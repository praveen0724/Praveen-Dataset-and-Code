# %% [markdown]
# #Objectives#
#
#
#
# *   The main goal of this notebook is to build a machine learning system that can predict GLD (gold) prices based on several other stock prices.
# *   Obtain data insights using pandas.
#
#
# *   Find the correlation of the other features with GLD (gold) stock price.
# *   Predict the GLD (gold) price by splitting the data and evaluate the model.

# %% [markdown]
# #Importing libraries#

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from math import sqrt

# %%
# Importing drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# loading the csv data to a Pandas DataFrame

dataset = pd.read_csv('/content/drive/MyDrive/Capstone project/gld_price_data.csv')

# %%
dataset
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# print first 5 rows in the dataframe

dataset.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
# print last 5 rows of the dataframe

dataset.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
# number of rows and columns

dataset.shape
# Out:
# (2290, 6)

# %%
dataset.columns
# Out:
# Index(['Date', 'SPX', 'GLD', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %% [markdown]
# ##**Data** **set** **columns**##
#
# *   Date - mm/dd/yyyy
#
# *   SPX - is a free-float weighted measurement stock market index of the 500 largest companies listed on stock exchanges in the United State
#
# *  GLD - Gold Price
# *  USO - United States Oil Fund
#
#
# * SLV - Silver Price
#
#
# *  EUR/USD - currency pair quotation of the Euro against the USD

# %% [markdown]
# #EDA#

# %%
# getting some basic informations about the data

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2285    False
# 2286    False
# 2287    False
# 2288    False
# 2289    False
# Length: 2290, dtype: bool

# %%
dataset.dropna()
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# checking the number of missing values

dataset.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
# getting the statistical measures of the data

dataset.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %% [markdown]
# #PLOTS#

# %%
#Histogram
dataset.hist(figsize=(12,10));
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Pair Plot

sns.pairplot(dataset)
plt.show()

# %%
#Box plot 

import warnings
warnings.filterwarnings('ignore') 

cols = ['SPX','GLD','USO','SLV','EUR/USD']
fig ,ax = plt.subplots(ncols=1,nrows=len(cols),figsize=(10,12))
for i in range(len(cols)):
    sns.boxplot(dataset[cols[i]],ax = ax[i])
plt.subplots_adjust(hspace=2)
plt.show()

# %%
#Distplot for SPX,GLD,USO,SLV,EUR/USD


import warnings
warnings.filterwarnings('ignore') 

cols = ['SPX','GLD','USO','SLV','EUR/USD']
fig ,ax = plt.subplots(ncols=1,nrows=len(cols),figsize=(10,12))
for i in range(len(cols)):
    sns.distplot(dataset[cols[i]],ax = ax[i])
plt.subplots_adjust(hspace=2)
plt.show()

# %%
# change date columns to datetime create year column 

dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset['Year'] = pd.DatetimeIndex(dataset['Date']).year

# %%
# plot Max VS Average yearly Gold prices

dataset.groupby('Year').max()['GLD'].plot(color = 'green',label = 'Max')
dataset.groupby('Year').mean()['GLD'].plot(color = 'blue',label = 'Average')
dataset.groupby('Year').min()['GLD'].plot(color = 'red',label = 'Min')
plt.ylabel('Gold Price')
plt.legend()
plt.title("Max VS Average Yearly Gold prices")
plt.grid()
plt.show();

# %%
#Scatter Plot 
dataset.plot(kind='scatter', x='SPX', y='GLD')

# %%
dataset.plot(kind='scatter', x='SLV', y='GLD')

# %%
dataset.plot(kind='scatter', x='EUR/USD', y='GLD')

# %%
dataset.plot(kind='scatter',x='USO',y='GLD')

# %% [markdown]
# #CORRELATION#

# %% [markdown]
#    1.Positive Correlation - if 1 value increases other value also increases. A correlation of 1.0 indicates a perfect positive correlation.
#
#
#    2.Negative Correlation -  if 1 value increases other value decreases. A correlation of -1.0 indicates a perfect negative correlation.

# %%
drop_year= dataset.drop(["Year"], axis = 1)
drop_year
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0    2008-01-02  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1    2008-01-03  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2    2008-01-04  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3    2008-01-07  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4    2008-01-08  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285 2018-05-08  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286 2018-05-09  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287 2018-05-10  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288 2018-05-14  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289 2018-05-16  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
#Drop Year in dataset
correlation = drop_year.corr()

# %%
# constructing a heatmap to understand the correlatiom
plt.figure(figsize = (8,8))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f',annot=True, annot_kws={'size':8}, cmap='Reds')
plt.title("Heat Map for Correlation",{'size':30})
# Out:
# Text(0.5, 1.0, 'Heat Map for Correlation')

# %% [markdown]
# Conclusion:
#
#
#
# *  Gold (GLD) and silver (SLV) are highly corelated to each other -> 0.9
# *   Gold (GLD) and Standard and Poor's 500 (SPX) are zero correlation -> 0.0
#
# *   Rest features expect gold (GLD) are negative correlated with respect to gold (GLD) -> -0.0 & -0.2

# %%
# correlation values of GLD

print(correlation['GLD'])
# Out:
# SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %% [markdown]
# #Linear Regression#

# %% [markdown]
# **Splitting the Features and Target**

# %%
X = dataset.drop(['Date','Year','GLD'],axis=1)
Y = dataset['GLD']

# %%
print(X)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %% [markdown]
# **Splitting into Training data and Test Data**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
model1 = LinearRegression()

# %%
# training the model

model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Model Evaluation#

# %%
# prediction on Test Data
test_data_prediction = model1.predict(X_test)

# %%
print(test_data_prediction)
# Out:
# [159.45290968  81.50858067 113.4868037  128.55153817 126.20403783
#  141.31818338 165.49416492 124.44197659 113.95389904 122.9965895
#  113.95492464 174.89529849 132.66890174 159.24793304 118.8791679
#  122.14315717 150.37153054 161.27175405 152.2792036  162.19946709
#  145.88372183 118.07669395 180.21729122 178.13331554 123.51701986
#   98.82914322  76.63486248 119.38435511 113.85027665 159.25706609
#   93.76037617 120.05334649  88.61086583 114.28801659 112.77954274
#  144.19518102 118.78252489 115.87334354 144.06409553 113.81864246
#  100.49676727  89.42842238 120.36720699 110.47635305 146.4894628
#  119.30321261 110.99311348 111.3386287   96.48139076 123.40842816
#   79.51413425 115.36111603 121.78896764 114.55367722 120.9074622
#  117.10612464 152.31198525 182.7735091  196.73570503  91.06670951
#  101.92097594  87.48443506  94.33158785 119.17357764 121.8935122
#  125.85678089 163.2699701  122.91100556 113.55098736 104.06905043
#  155.16775229 176.87972077 125.62460858 113.85896766 119.69577146
#  120.03159609 117.85194226 118.35897733 113.72954121 129.97412373
#  121.74279861 104.64163725 117.17374823 126.31757797  94.63054496
#   88.6429881  173.79414659 123.3889615  121.11367109 106.85139516
#  102.43120839  75.64721451 160.63204133 116.53485791 123.43284852
#  128.90964962 141.9754171   94.90681665 140.59107397 150.88254462
#  120.61400122 126.18758167 126.15751557 117.79050312 120.23630249
#   96.07847005 108.46289277 160.74032164 149.25506194 116.90461024
#  101.89683477  78.55100685 113.55252108 121.86482779 111.50766509
#  119.97033408 144.93538115 150.48099293 120.46444466 148.63103233
#  102.36169588 113.04232004 116.67313346 114.17074491 111.72097362
#  149.60529086 103.27069375 162.8243783  127.26240013 159.3553434
#  122.69414947 123.01751489 121.65730575 114.16407868 119.73006341
#  121.6690294  110.41148326  93.51351227 120.88718035 105.29371566
#  105.74311748 121.82956746 123.37061551 104.36058862 124.41163091
#  157.15019835  90.2875932  111.75426942 116.24341673 129.71742482
#  123.86401547 110.41664959 124.85086427 100.6794172   94.36971456
#  105.71510695 122.36927215  79.9786057  126.70980467 152.88190713
#  114.88722911 114.97966394 119.08904866 116.79453493 122.84487067
#  120.91030351 120.88673239 105.0696433  191.90883411 122.59664436
#  116.62755088  77.84989594 124.65745662 143.2709885  120.37043229
#  121.03655506  94.50745135 111.36682253 119.75471172 112.48632277
#   79.13563026 142.62965128 121.89588529 113.07538385  88.3918062
#  114.03342237 163.40511021 125.20580519 152.11443433 113.25319918
#  118.62431992 117.28641957 104.68078767 118.41921617 126.05035311
#  120.41292474 100.69533386 143.8328044  121.01265419 160.52275467
#  149.57414181 108.42224119 120.97109044 158.885207   118.21457812
#  158.11607219 143.83779103 120.47800019 159.86639242 111.24045013
#  126.4542079  144.93505484 106.94838427]

# %%
# Evaluate model

Rmse =metrics.mean_squared_error(Y_test, test_data_prediction)
r_2 = metrics.r2_score(Y_test, test_data_prediction)

print (f'R-Squared error = {r_2}')
print('RMSE : ',Rmse)
# Out:
# R-Squared error = 0.8657886565869237
# RMSE :  70.7889007972153

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='red', label = 'Actual Value')
plt.plot(test_data_prediction, color='blue', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()

# %% [markdown]
# ##Linear regression using OLS##

# %%
X = dataset.drop(['Date','Year','GLD'],axis=1)
Y = dataset['GLD']

# %%
scaler = MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size = 0.20, random_state=10)

# %%
# a statistical method of analysis that estimates the relationship between one or more independent variables and a dependent variable;
OLS_model = LinearRegression()

# %%
# fit the model
OLS_model.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
# predict the values
y_pred_OLS = OLS_model.predict(Xtest)

# %%
# compute the R-Squared
r_squared_OLS = OLS_model.score(Xtrain,Ytrain)

# Compute RMSE
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse_OLS = sqrt(mean_squared_error(Ytest, y_pred_OLS))
print('R-square:',r_squared_OLS)
print("RMSE_OLS:",rmse_OLS)
# Out:
# R-square: 0.8792902894467479
# RMSE_OLS: 8.311214915731478

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='red', label = 'Actual Value')
plt.plot( y_pred_OLS, color='blue', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()

# %% [markdown]
# ##Linear regression using Stochastic Gradient Descent (SGD)##

# %%
# build the model
SGD_model = SGDRegressor()

# fit the model
SGD_model.fit(Xtrain, Ytrain)
# Out:
# SGDRegressor()

# %%
# predict the values
y_pred_SGD  = SGD_model.predict(Xtest)

# %%
# compute the R-Squared
r_squared_SGD = SGD_model.score(Xtrain,Ytrain)

# Compute RMSE
rmse_SGD = sqrt(mean_squared_error(Ytest, y_pred_SGD))
print('R-square_SGD:',r_squared_SGD)
print("RMSE_SGD:",rmse_SGD)
# Out:
# R-square_SGD: -3.1935703137194225e+24
# RMSE_SGD: 42447041062561.086

# %%
Ytest = list(Ytest)

# %%
plt.plot(Y_test, color='red', label = 'Actual Value')
plt.plot( y_pred_SGD, color='blue', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()

# %% [markdown]
# ##Random Forest Regressor##

# %%
X = dataset.drop(['Date','Year','GLD'],axis=1)
Y = dataset['GLD']

# %%
print(X)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(Y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
regressor = RandomForestRegressor()

# %%
# training the model
regressor.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
# prediction on Test Data
test
#   86.2873993  124.65759989 150.00569755  89.5305002  106.79379998
#  108.90579994  84.82359881 136.30659999 154.96720194 137.60120388
#   74.11920001 152.59050215 126.26479975 126.80810019 127.49429913
#  108.4560993  156.22509913 114.4989012  116.9019012  125.30419932
#  154.23330119 121.28340007 156.37089891  92.98260048 125.53220128
#  126.13440045  87.94360037  92.25079939 126.29399907 128.38790374
#  113.20030065 117.80979752 120.98690012 126.96229784 120.04060084
#  135.91139983  93.86639901 119.91250055 113.32010108  94.38569966
#  108.82759992  87.2422991  108.7837991   89.64399988  92.49240014
#  131.52260223 162.43979986  89.33759993 119.52310078 133.55570222
#  123.69180015 128.51540213 102.01189848  88.97989922 131.2656011
#  120.60020014 108.71030011 168.11630115 115.09010021  86.57049896
#  119.04130065  90.99569965 161.71930062 116.31730065 121.56640017
#  160.29669825 120.17849935 112.63939957 108.51389868 126.72490028
#   75.74490046 103.0230997  127.55100279 122.03349889  92.63289991
#  132.07360094 118.26940117 115.82700028 154.05450336 158.55020113
#  110.20599958 156.13379799 119.39960104 160.74120169 118.47689998
#  158.45019967 115.11739967 116.65740041 149.119899   114.86260102
#  125.67389871 166.56159913 117.5391003  125.09639917 153.21320388
#  153.4523022  132.22980041 114.74020054 121.23520228 124.69770068
#   90.00410011 123.02630026 155.0341022  111.72520057 106.5461998
#  161.4906011  118.54889946 165.79110029 133.94930132 114.59529997
#  152.85359858 168.59369948 114.76920033 113.88530142 157.60719838
#   85.43429875 127.08400037 127.81100065 128.88589951 124.40360071
#  123.76690036  90.57450087 153.38770031  97.10379985 136.96630007
#   89.12089953 107.03279974 114.94860022 112.78330099 124.04869934
#   91.47999886 125.38210112 162.41749889 119.8584991  165.14190108
#  126.80579835 112.36380023 127.47449901  95.18989908  91.01469973
#  103.30709937 120.87170002  83.38919965 126.38650014 160.30290506
#  117.11070072 118.46149977 119.91419992 122.79099991 120.20660134
#  121.50369993 118.45260054 106.90079979 148.10189933 126.22599897
#  115.7040006   74.08529998 127.87790118 153.61380072 122.77310006
#  125.55570035  88.93689991 103.66349854 124.68100056 120.1595005
#   73.45480054 151.81030089 121.23450033 104.81440014  86.51059795
#  115.5237988  172.12699927 119.97220043 159.72109727 113.13249941
#  121.08730002 118.46210117  96.00729984 118.8623999  125.91760056
#  118.45899966  95.95130055 154.04420174 121.93110003 147.20680049
#  159.52630224 113.89380029 122.5238994  148.54149812 127.29710027
#  165.5945     135.66170029 120.13879973 167.50439841 108.46999942
#  121.94369865 138.16850073 106.01199905]

# %%
# R squared error
error_score = metrics.r2_score(Y_test, test_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9889624241399165

# %%
mean=metrics.mean_squared_error(Y_test, test_prediction )
print('RMSE :',mean)
# Out:
# RMSE : 5.821697650372084

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='red', label = 'Actual Value')
plt.plot( test_prediction, color='blue', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()

# %% [markdown]
# ##DecisionTreeRegressior##

# %%
X = dataset.drop(['Date','Year','GLD'],axis=1)
Y = dataset['GLD']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
reg = DecisionTreeRegressor()

# %%
# training the model
reg.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
# prediction on Test Data
test_data = regressor.predict(X_test)

# %%
# R squared error
error_score = metrics.r2_score(Y_test, test_data)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9889624241399165

# %%
meee=metrics.mean_squared_error(Y_test, test_data )
print('RMSE : ',meee)
# Out:
# RMSE :  5.821697650372084

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='red', label = 'Actual Value')
plt.plot( test_data, color='blue', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()
